# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.60-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (2024.2.2)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (3.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (10.2.0)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (4.66.2)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from matplotlib->roboflow) (4.48.1)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from matplotlib->roboflow) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/argos_env/lib/python3.12/site-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.60-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 12.3 MB/s eta 0:00:0000:0100:01
# Downloading pillow_heif-0.22.0-cp312-cp312-macosx_14_0_arm64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: filetype, pillow-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lightly 1.4.26 requires pydantic<2,>=1.10.5, but you have pydantic 2.9.2 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 requests-toolbelt-1.0.0 roboflow-1.1.60

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="MQ2C0IkThNDNcumZMMA5")
project = rf.workspace("john-koleosho-3hd0h").project("parcels-with-defect")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Parcels-with-Defect-1 to yolov8-obb:: 100%|██████████| 34548/34548 [00:03<00:00, 10543.22it/s]
# Extracting Dataset Version Zip to Parcels-with-Defect-1 in yolov8-obb:: 100%|██████████| 1122/1122 [00:00<00:00, 5502.64it/s]
